# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

# %%
# Read CSV in as a dataframe
df = pd.read_csv('Data/census_data.csv')

# Print df
df
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 1                               17.2                          8.8
# 2                               24.0                          8.9
# 3                               10.9                          8.2
# 4                                7.5                          5.2
# ..                               ...                          ...
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           18.2
# 1                                           20.8
# 2                                           11.8
# 3                                           13.4
# 4                                            4.5
# ..                                           ...
# 73                                           4.3
# 74                                          10.8
# 75                                          10.9
# 76                                           9.7
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                               27.5               23939            39.0
# 1                               38.5               23040            46.0
# 2                               22.2               35787            20.0
# 3                               25.5               37524            17.0
# 4                               26.2               57123             6.0
# ..                               ...                 ...             ...
# 73                              36.8               34381            16.0
# 74                              40.3               27149            30.0
# 75                              30.3               25828            24.0
# 76                              23.8               33385            19.0
# 77                              33.5               28202             NaN
#
# [78 rows x 9 columns]

# %%
# First five rows of the dataframe
df.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              27.5               23939            39.0
# 1                              38.5               23040            46.0
# 2                              22.2               35787            20.0
# 3                              25.5               37524            17.0
# 4                              26.2               57123             6.0

# %%
# See statistical summary 
df.describe()
# Out:
#        Community Area Number  PERCENT OF HOUSING CROWDED  \
# count              77.000000                   78.000000
# mean               39.000000                    4.920513
# std                22.371857                    3.658981
# min                 1.000000                    0.300000
# 25%                20.000000                    2.325000
# 50%                39.000000                    3.850000
# 75%                58.000000                    6.800000
# max                77.000000                   15.800000
#
#        PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# count                         78.000000                    78.000000
# mean                          21.739744                    15.341026
# std                           11.457231                     7.499497
# min                            3.300000                     4.700000
# 25%                           13.350000                     9.200000
# 50%                           19.050000                    13.850000
# 75%                           29.150000                    20.000000
# max                           56.500000                    35.900000
#
#        PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# count                                     78.000000
# mean                                      20.330769
# std                                       11.746514
# min                                        2.500000
# 25%                                       12.075000
# 50%                                       18.650000
# 75%                                       26.600000
# max                                       54.800000
#
#        PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# count                         78.000000           78.000000       77.000000
# mean                          35.717949        25597.000000       49.506494
# std                            7.284421        15196.405541       28.690556
# min                           13.500000         8201.000000        1.000000
# 25%                           32.150000        15804.750000       25.000000
# 50%                           38.050000        21668.500000       50.000000
# 75%                           40.500000        28715.750000       74.000000
# max                           51.500000        88669.000000       98.000000

# %%
# See quick summary of dataset
df.info
# Out:
# <bound method DataFrame.info of     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 1                               17.2                          8.8
# 2                               24.0                          8.9
# 3                               10.9                          8.2
# 4                                7.5                          5.2
# ..                               ...                          ...
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           18.2
# 1                                           20.8
# 2                                           11.8
# 3                                           13.4
# 4                                            4.5
# ..                                           ...
# 73                                           4.3
# 74                                          10.8
# 75                                          10.9
# 76                                           9.7
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                               27.5               23939            39.0
# 1                               38.5               23040            46.0
# 2                               22.2               35787            20.0
# 3                               25.5               37524            17.0
# 4                               26.2               57123             6.0
# ..                               ...                 ...             ...
# 73                              36.8               34381            16.0
# 74                              40.3               27149            30.0
# 75                              30.3               25828            24.0
# 76                              23.8               33385            19.0
# 77                              33.5               28202             NaN
#
# [78 rows x 9 columns]>

# %%
#Data types
df.dtypes
# Out:
# Community Area Number                           float64
# COMMUNITY AREA NAME                              object
# PERCENT OF HOUSING CROWDED                      float64
# PERCENT HOUSEHOLDS BELOW POVERTY                float64
# PERCENT AGED 16+ UNEMPLOYED                     float64
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    float64
# PERCENT AGED UNDER 18 OR OVER 64                float64
# PER CAPITA INCOME                                 int64
# HARDSHIP INDEX                                  float64
# dtype: object

# %%
#Check for missing values
df.isna()
# Out:
#     Community Area Number  COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                   False                False                       False
# 1                   False                False                       False
# 2                   False                False                       False
# 3                   False                False                       False
# 4                   False                False                       False
# ..                    ...                  ...                         ...
# 73                  False                False                       False
# 74                  False                False                       False
# 75                  False                False                       False
# 76                  False                False                       False
# 77                   True                False                       False
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# 4                              False                        False
# ..                               ...                          ...
# 73                             False                        False
# 74                             False                        False
# 75                             False                        False
# 76                             False                        False
# 77                             False                        False
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ..                                           ...
# 73                                         False
# 74                                         False
# 75                                         False
# 76                                         False
# 77                                         False
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              False               False           False
# 1                              False               False           False
# 2                              False               False           False
# 3                              False               False           False
# 4                              False               False           False
# ..                               ...                 ...             ...
# 73                             False               False           False
# 74                             False               False           False
# 75                             False               False           False
# 76                             False               False           False
# 77                             False               False            True
#
# [78 rows x 9 columns]

# %%
#Check for duplicates 
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Length: 78, dtype: bool

# %%
# Top 5 lowest poverty 
p_level = df.sort_values(by="PERCENT HOUSEHOLDS BELOW POVERTY", ascending=True)
top_p_level = p_level.head(5)
top_p_level
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 8                     9.0         Edison Park                         1.1
# 73                   74.0     Mount Greenwood                         1.0
# 71                   72.0             Beverly                         0.9
# 9                    10.0        Norwood Park                         2.0
# 4                     5.0        North Center                         0.3
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 8                                3.3                          6.5
# 73                               3.4                          8.7
# 71                               5.1                          8.0
# 9                                5.4                          9.0
# 4                                7.5                          5.2
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 8                                            7.4
# 73                                           4.3
# 71                                           3.7
# 9                                           11.5
# 4                                            4.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 8                               35.3               40959             8.0
# 73                              36.8               34381            16.0
# 71                              40.5               39523            12.0
# 9                               39.5               32875            21.0
# 4                               26.2               57123             6.0

# %%
# Bar Chart
x = top_p_level["COMMUNITY AREA NAME"]
y = top_p_level["PERCENT HOUSEHOLDS BELOW POVERTY"]

# Create a bar chart
plt.bar(x, y)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('Percent Households Below Poverty')
plt.title('Chicago Community Area with Lowest Poverty Levels')

# Show the plot
plt.show()

#What should the Y value be out of? 
#How to tilt the X labels and increase chart size so that they legible?
#sort so that the highest one is first

# %%
# Top 5 highest education 
e_level = df.sort_values(by="PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA", ascending=True)
top_e_level = e_level.head(5)
top_e_level
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 7                     8.0     Near North Side                         1.9
# 5                     6.0           Lake View                         1.1
# 31                   32.0                Loop                         1.5
# 6                     7.0        Lincoln Park                         0.8
# 71                   72.0             Beverly                         0.9
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 7                               12.9                          7.0
# 5                               11.4                          4.7
# 31                              14.7                          5.7
# 6                               12.3                          5.1
# 71                               5.1                          8.0
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 7                                            2.5
# 5                                            2.6
# 31                                           3.1
# 6                                            3.6
# 71                                           3.7
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 7                               22.6               88669             1.0
# 5                               17.0               60058             5.0
# 31                              13.5               65526             3.0
# 6                               21.5               71551             2.0
# 71                              40.5               39523            12.0

# %%
x = top_e_level["COMMUNITY AREA NAME"]
y = top_e_level["PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA"]

# Create a bar chart
plt.bar(x, y)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA')
plt.title('Chicago Community Area with Highest Education Levels')

# Show the plot

#What should the Y value be out of? 
#How to tilt the X labels and increase chart size so that they legible?
#sort so that the highest one is first
plt.show()

# %%
# Top 5 lowest unemployment
u_level = df.sort_values(by="PERCENT AGED 16+ UNEMPLOYED", ascending=True)
top_u_level = u_level.head(5)
top_u_level
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 5                     6.0           Lake View                         1.1
# 32                   33.0     Near South Side                         1.3
# 6                     7.0        Lincoln Park                         0.8
# 4                     5.0        North Center                         0.3
# 31                   32.0                Loop                         1.5
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 5                               11.4                          4.7
# 32                              13.8                          4.9
# 6                               12.3                          5.1
# 4                                7.5                          5.2
# 31                              14.7                          5.7
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 5                                            2.6
# 32                                           7.4
# 6                                            3.6
# 4                                            4.5
# 31                                           3.1
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 5                               17.0               60058             5.0
# 32                              21.8               59077             7.0
# 6                               21.5               71551             2.0
# 4                               26.2               57123             6.0
# 31                              13.5               65526             3.0

# %%
x = top_u_level["COMMUNITY AREA NAME"]
y = top_u_level["PERCENT AGED 16+ UNEMPLOYED"]

# Create a bar chart
plt.bar(x, y)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('PERCENT AGED 16+ UNEMPLOYED')
plt.title('Chicago Community Area with Lowest Unemployment Levels')

# Show the plot
plt.show()

#What should the Y value be out of? 
#How to tilt the X labels and increase chart size so that they legible?
#sort so that the highest one is first

# %%
df["PER CAPITA INCOME "]
# Out:
# 0     23939
# 1     23040
# 2     35787
# 3     37524
# 4     57123
#       ...
# 73    34381
# 74    27149
# 75    25828
# 76    33385
# 77    28202
# Name: PER CAPITA INCOME , Length: 78, dtype: int64

# %%
#Key Error

# Top 5 highest per capita 
per_capita_level = df.sort_values(by="PER CAPITA INCOME", ascending=True)
top_per_capita = per_capita_level.head(5)
top_per_capita
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kaylagranados/Desktop/Data_Projects/240302 Chicago Socioeconomic Status /chicago_socioeconomic_status/EDA and Linear Regression.ipynb Cell 15 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000014?line=0'>1</a> #Key Error
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000014?line=1'>2</a>
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000014?line=2'>3</a> # Top 5 highest per capita
# ----> <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000014?line=3'>4</a> per_capita_level = df.sort_values(by="PER CAPITA INCOME", ascending=True)
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000014?line=4'>5</a> top_per_capita = per_capita_level.head(5)
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000014?line=5'>6</a> top_per_capita
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
#    6315     # need to rewrap column in Series to apply key function
#    6316     if key is not None:
#    6317         # error: Incompatible types in assignment (expression has type
#    6318         # "Series", variable has type "ndarray")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'PER CAPITA INCOME'

# %%
#Unsure why this is giving a key error

x = top_per_capita["COMMUNITY AREA NAME"]
y = top_per_capita["PER CAPITA INCOME"]

# Create a bar chart
plt.bar(x, y)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('PER CAPITA INCOME')
plt.title('Chicago Community Area with Lowest Poverty Levels')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PER CAPITA INCOME'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/kaylagranados/Desktop/Data_Projects/240302 Chicago Socioeconomic Status /chicago_socioeconomic_status/socioeconomic_EDA.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/socioeconomic_EDA.ipynb#ch0000016?line=0'>1</a> x = top_per_capita["COMMUNITY AREA NAME"]
# ----> <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/socioeconomic_EDA.ipynb#ch0000016?line=1'>2</a> y = top_per_capita["PER CAPITA INCOME"]
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/socioeconomic_EDA.ipynb#ch0000016?line=3'>4</a> # Create a bar chart
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/socioeconomic_EDA.ipynb#ch0000016?line=4'>5</a> plt.bar(x, y)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'PER CAPITA INCOME'

# %%
# Create a histogram
plt.hist(df['PERCENT OF HOUSING CROWDED'], bins=5, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Test')
plt.ylabel('Test')
plt.title('Histogram')

# Show the plot
plt.show()

# %%
# Create a histogram
plt.hist(df['PERCENT HOUSEHOLDS BELOW POVERTY'], bins=5, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Test')
plt.ylabel('Test')
plt.title('Histogram')

# Show the plot
plt.show()

# %%
# Create a histogram
plt.hist(df['PERCENT AGED 16+ UNEMPLOYED'], bins=5, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Test')
plt.ylabel('Test')
plt.title('Histogram')

# Show the plot
plt.show()

# %%
# Create a histogram
plt.hist(df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA'], bins=5, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Test')
plt.ylabel('Test')
plt.title('Histogram')

# Show the plot
plt.show()

# %%
#key error again for per capita income

# Create a histogram
plt.hist(df["PER CAPITA INCOME"], bins=5, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Test')
plt.ylabel('Test')
plt.title('Histogram')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PER CAPITA INCOME'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/kaylagranados/Desktop/Data_Projects/240302 Chicago Socioeconomic Status /chicago_socioeconomic_status/EDA and Linear Regression.ipynb Cell 21 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000020?line=0'>1</a> #key error again for per capita income
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000020?line=1'>2</a>
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000020?line=2'>3</a> # Create a histogram
# ----> <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000020?line=3'>4</a> plt.hist(df["PER CAPITA INCOME"], bins=5, color='skyblue', edgecolor='black')
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000020?line=5'>6</a> # Add labels and title
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000020?line=6'>7</a> plt.xlabel('Test')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'PER CAPITA INCOME'

# %%
# Create a scatter plot
plt.scatter(df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA'], df['PERCENT HOUSEHOLDS BELOW POVERTY'])

# Add labels and title
plt.xlabel('Education')
plt.ylabel('Poverty')
plt.title('Scatter Plot Example')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['PERCENT AGED 16+ UNEMPLOYED'], df['PERCENT HOUSEHOLDS BELOW POVERTY'])

# Add labels and title
plt.xlabel('Unemployment')
plt.ylabel('Poverty')
plt.title('Scatter Plot Example')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['PERCENT OF HOUSING CROWDED'], df['PERCENT HOUSEHOLDS BELOW POVERTY'])

# Add labels and title
plt.xlabel('Crowded Housing')
plt.ylabel('Poverty')
plt.title('Scatter Plot Example')

# Show the plot
plt.show()

# %%
#Calcuate coefficient
correlation_matrix = df.corr()
correlation_matrix

#for all columns? 
#remove community area number
# Out:
#                                               Community Area Number  \
# Community Area Number                                      1.000000
# PERCENT OF HOUSING CROWDED                                 0.002316
# PERCENT HOUSEHOLDS BELOW POVERTY                           0.147414
# PERCENT AGED 16+ UNEMPLOYED                                0.376196
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA               0.175969
# PERCENT AGED UNDER 18 OR OVER 64                           0.428011
# PER CAPITA INCOME                                         -0.398344
# HARDSHIP INDEX                                             0.314853
#
#                                               PERCENT OF HOUSING CROWDED  \
# Community Area Number                                           0.002316
# PERCENT OF HOUSING CROWDED                                      1.000000
# PERCENT HOUSEHOLDS BELOW POVERTY                                0.319403
# PERCENT AGED 16+ UNEMPLOYED                                     0.165299
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                    0.875959
# PERCENT AGED UNDER 18 OR OVER 64                                0.224692
# PER CAPITA INCOME                                              -0.541730
# HARDSHIP INDEX                                                  0.649574
#
#                                               PERCENT HOUSEHOLDS BELOW POVERTY  \
# Community Area Number                                                 0.147414
# PERCENT OF HOUSING CROWDED                                            0.319403
# PERCENT HOUSEHOLDS BELOW POVERTY                                      1.000000
# PERCENT AGED 16+ UNEMPLOYED                                           0.800084
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                          0.424294
# PERCENT AGED UNDER 18 OR OVER 64                                      0.435894
# PER CAPITA INCOME                                                    -0.567025
# HARDSHIP INDEX                                                        0.803267
#
#                                               PERCENT AGED 16+ UNEMPLOYED  \
# Community Area Number                                            0.376196
# PERCENT OF HOUSING CROWDED                                       0.165299
# PERCENT HOUSEHOLDS BELOW POVERTY                                 0.800084
# PERCENT AGED 16+ UNEMPLOYED                                      1.000000
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                     0.355518
# PERCENT AGED UNDER 18 OR OVER 64                                 0.676532
# PER CAPITA INCOME                                               -0.656619
# HARDSHIP INDEX                                                   0.792294
#
#                                               PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# Community Area Number                                                             0.175969
# PERCENT OF HOUSING CROWDED                                                        0.875959
# PERCENT HOUSEHOLDS BELOW POVERTY                                                  0.424294
# PERCENT AGED 16+ UNEMPLOYED                                                       0.355518
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                                      1.000000
# PERCENT AGED UNDER 18 OR OVER 64                                                  0.408878
# PER CAPITA INCOME                                                                -0.709770
# HARDSHIP INDEX                                                                    0.802538
#
#                                               PERCENT AGED UNDER 18 OR OVER 64  \
# Community Area Number                                                 0.428011
# PERCENT OF HOUSING CROWDED                                            0.224692
# PERCENT HOUSEHOLDS BELOW POVERTY                                      0.435894
# PERCENT AGED 16+ UNEMPLOYED                                           0.676532
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                          0.408878
# PERCENT AGED UNDER 18 OR OVER 64                                      1.000000
# PER CAPITA INCOME                                                    -0.754844
# HARDSHIP INDEX                                                        0.690844
#
#                                               PER CAPITA INCOME   \
# Community Area Number                                  -0.398344
# PERCENT OF HOUSING CROWDED                             -0.541730
# PERCENT HOUSEHOLDS BELOW POVERTY                       -0.567025
# PERCENT AGED 16+ UNEMPLOYED                            -0.656619
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA           -0.709770
# PERCENT AGED UNDER 18 OR OVER 64                       -0.754844
# PER CAPITA INCOME                                       1.000000
# HARDSHIP INDEX                                         -0.849167
#
#                                               HARDSHIP INDEX
# Community Area Number                               0.314853
# PERCENT OF HOUSING CROWDED                          0.649574
# PERCENT HOUSEHOLDS BELOW POVERTY                    0.803267
# PERCENT AGED 16+ UNEMPLOYED                         0.792294
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA        0.802538
# PERCENT AGED UNDER 18 OR OVER 64                    0.690844
# PER CAPITA INCOME                                  -0.849167
# HARDSHIP INDEX                                      1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='flare', fmt=".2f", square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
#could be interesting if I chose specific columns for this
sns.pairplot(df)
plt.show()

# %%
#Create scatter plot 
scatter_plot = df.plot(kind="scatter", x="PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Scatter Plot", color='c')

# Create x and y values 
x_values=df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regress 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'blue')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 0.41x + 13.33

# %%
#Create scatter plot 
scatter_plot = df.plot(kind="scatter", x="PERCENT AGED 16+ UNEMPLOYED", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Scatter Plot", color='c')

# Create x and y values 
x_values=df['PERCENT AGED 16+ UNEMPLOYED']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regress 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'blue')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 1.22x + 2.99

# %%
#Create scatter plot 
scatter_plot = df.plot(kind="scatter", x="PERCENT OF HOUSING CROWDED", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Scatter Plot", color='c')

# Create x and y values 
x_values=df['PERCENT OF HOUSING CROWDED']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regress 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'blue')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 1.0x + 16.82
