# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

# %%
# Read CSV in as a dataframe
df = pd.read_csv('Data/census_data.csv')

# Print df
df
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# ...

# %%
# First five rows of the dataframe
df.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# ...

# %%
#drop hardship index
df.drop(["HARDSHIP INDEX"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kaylagranados/Desktop/Data_Projects/240302 Chicago Socioeconomic Status /chicago_socioeconomic_status/EDA and Linear Regression.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000032?line=0'>1</a> #drop hardship index
# ----> <a href='vscode-notebook-cell:/Users/kaylagranados/Desktop/Data_Projects/240302%20Chicago%20Socioeconomic%20Status%20/chicago_socioeconomic_status/EDA%20and%20Linear%20Regression.ipynb#ch0000032?line=1'>2</a> df.drop(["HARDSHIP INDEX"])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
# See statistical summary 
df.describe()
# Out:
#        Community Area Number  PERCENT OF HOUSING CROWDED  \
# count              77.000000                   78.000000
# mean               39.000000                    4.920513
# std                22.371857                    3.658981
# min                 1.000000                    0.300000
# 25%                20.000000                    2.325000
# 50%                39.000000                    3.850000
# 75%                58.000000                    6.800000
# max                77.000000                   15.800000
#
#        PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# count                         78.000000                    78.000000
# mean                          21.739744                    15.341026
# std                           11.457231                     7.499497
# min                            3.300000                     4.700000
# 25%                           13.350000                     9.200000
# ...

# %%
#Data types
df.dtypes
# Out:
# Community Area Number                           float64
# COMMUNITY AREA NAME                              object
# PERCENT OF HOUSING CROWDED                      float64
# PERCENT HOUSEHOLDS BELOW POVERTY                float64
# PERCENT AGED 16+ UNEMPLOYED                     float64
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    float64
# PERCENT AGED UNDER 18 OR OVER 64                float64
# PER CAPITA INCOME                                 int64
# HARDSHIP INDEX                                  float64
# dtype: object

# %%
#Check for missing values
df.isna()
# Out:
#     Community Area Number  COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                   False                False                       False
# 1                   False                False                       False
# 2                   False                False                       False
# 3                   False                False                       False
# 4                   False                False                       False
# ..                    ...                  ...                         ...
# 73                  False                False                       False
# 74                  False                False                       False
# 75                  False                False                       False
# 76                  False                False                       False
# 77                   True                False                       False
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# ...

# %%
#Check for duplicates 
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Length: 78, dtype: bool

# %%
# Top 5 lowest poverty 
p_level = df.sort_values(by="PERCENT HOUSEHOLDS BELOW POVERTY", ascending=True)
top_p_level = p_level.head(5)
top_p_level
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 8                     9.0         Edison Park                         1.1
# 73                   74.0     Mount Greenwood                         1.0
# 71                   72.0             Beverly                         0.9
# 9                    10.0        Norwood Park                         2.0
# 4                     5.0        North Center                         0.3
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 8                                3.3                          6.5
# 73                               3.4                          8.7
# 71                               5.1                          8.0
# 9                                5.4                          9.0
# 4                                7.5                          5.2
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 8                                            7.4
# ...

# %%
# Top 5 highest poverty 
p_level = df.sort_values(by="PERCENT HOUSEHOLDS BELOW POVERTY", ascending=False)
top_p_level = p_level.head(5)
top_p_level
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 53                   54.0           Riverdale                         5.8
# 36                   37.0         Fuller Park                         3.2
# 67                   68.0           Englewood                         3.8
# 28                   29.0      North Lawndale                         7.4
# 26                   27.0  East Garfield Park                         8.2
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 53                              56.5                         34.6
# 36                              51.2                         33.9
# 67                              46.6                         28.0
# 28                              43.1                         21.2
# 26                              42.4                         19.6
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 53                                          27.5
# ...

# %%
# Bar Chart
x = top_p_level["COMMUNITY AREA NAME"]
y = top_p_level["PERCENT HOUSEHOLDS BELOW POVERTY"]

# Create a bar chart
colors = ['#33CAFF', '#33AFFF', '#338AFF', '#3355FF', '#3633FF']
plt.bar(x, y, color=colors)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('Percent Households Below Poverty')
plt.title('Chicago Community Area with Lowest Poverty Levels')

# Rotate X axis
plt.xticks(rotation=20) 

# Show the plot
plt.show()

#What should the Y value be out of? 
#sort so that the highest one is first

# %%
# Top 5 highest education 
e_level = df.sort_values(by="PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA", ascending=True)
top_e_level = e_level.head(5)
top_e_level
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 7                     8.0     Near North Side                         1.9
# 5                     6.0           Lake View                         1.1
# 31                   32.0                Loop                         1.5
# 6                     7.0        Lincoln Park                         0.8
# 71                   72.0             Beverly                         0.9
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 7                               12.9                          7.0
# 5                               11.4                          4.7
# 31                              14.7                          5.7
# 6                               12.3                          5.1
# 71                               5.1                          8.0
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 7                                            2.5
# ...

# %%
x = top_e_level["COMMUNITY AREA NAME"]
y = top_e_level["PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA"]

# Create a bar chart
colors = ['#33CAFF', '#33AFFF', '#338AFF', '#3355FF', '#3633FF']
plt.bar(x, y, color=colors)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA')
plt.title('Chicago Community Area with Highest Education Levels')

# Rotate X axis
plt.xticks(rotation=20) 

# Show the plot

#What should the Y value be out of? 
plt.show()

# %%
# Top 5 lowest unemployment
u_level = df.sort_values(by="PERCENT AGED 16+ UNEMPLOYED", ascending=True)
top_u_level = u_level.head(5)
top_u_level
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 5                     6.0           Lake View                         1.1
# 32                   33.0     Near South Side                         1.3
# 6                     7.0        Lincoln Park                         0.8
# 4                     5.0        North Center                         0.3
# 31                   32.0                Loop                         1.5
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 5                               11.4                          4.7
# 32                              13.8                          4.9
# 6                               12.3                          5.1
# 4                                7.5                          5.2
# 31                              14.7                          5.7
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 5                                            2.6
# ...

# %%
x = top_u_level["COMMUNITY AREA NAME"]
y = top_u_level["PERCENT AGED 16+ UNEMPLOYED"]

# Create a bar chart
colors = ['#33CAFF', '#33AFFF', '#338AFF', '#3355FF', '#3633FF']
plt.bar(x, y, color=colors)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('PERCENT AGED 16+ UNEMPLOYED')
plt.title('Chicago Community Area with Lowest Unemployment Levels')

# Rotate X axis
plt.xticks(rotation=20) 

# Show the plot
plt.show()

#What should the Y value be out of?

# %%
# Top 5 highest per capita 
per_capita_level = df.sort_values(by="PER CAPITA INCOME", ascending=False)
top_per_capita = per_capita_level.head(5)
top_per_capita
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 7                     8.0     Near North Side                         1.9
# 6                     7.0        Lincoln Park                         0.8
# 31                   32.0                Loop                         1.5
# 5                     6.0           Lake View                         1.1
# 32                   33.0     Near South Side                         1.3
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 7                               12.9                          7.0
# 6                               12.3                          5.1
# 31                              14.7                          5.7
# 5                               11.4                          4.7
# 32                              13.8                          4.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 7                                            2.5
# ...

# %%
x = top_per_capita["COMMUNITY AREA NAME"]
y = top_per_capita["PER CAPITA INCOME"]

# Create a bar chart
colors = ['#33CAFF', '#33AFFF', '#338AFF', '#3355FF', '#3633FF']
plt.bar(x, y, color=colors)

# Add labels and title
plt.xlabel('Community Areas')
plt.ylabel('PER CAPITA INCOME')
plt.title('Chicago Community Area with Highest Per Capita Income')

# Rotate X axis
plt.xticks(rotation=20) 

# Show the plot
plt.show()

# %%
# Create a histogram
plt.hist(df['PERCENT OF HOUSING CROWDED'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percent of Housing Crowded')
plt.ylabel('Frequency')
plt.title('Frequency of Housing Crowded Percentage')

# Show the plot
plt.show()

# %%
# Create histogram
plt.hist(df['PERCENT HOUSEHOLDS BELOW POVERTY'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percent Households Below Poverty')
plt.ylabel('Frequency')
plt.title('Frequency of Percent Households Below Poverty')

# Show the plot
plt.show()

# %%
# Create histogram
plt.hist(df['PERCENT AGED 16+ UNEMPLOYED'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percent Aged 16+ Unemployed')
plt.ylabel('Frequency')
plt.title('Frequency of Unemployement Percentage')

# Show the plot
plt.show()

# %%
# Create histogram
plt.hist(df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percent aged 25+ without high school diploma')
plt.ylabel('Frequency')
plt.title('Frequency of Percentage without High School Diploma')

# Show the plot
plt.show()

# %%
# Create histogram
plt.hist(df["PER CAPITA INCOME"], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Per Capita Income')
plt.ylabel('Frequency')
plt.title('Frequencey of Per Capita Income')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA'], df['PERCENT HOUSEHOLDS BELOW POVERTY'])

# Add labels and title
plt.xlabel('Percent of Aged 25+ Without High School Diploma')
plt.ylabel('Percent of Households Below Poverty')
plt.title('High School Diploma vs Poverty Level')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['PERCENT AGED 16+ UNEMPLOYED'], df['PERCENT HOUSEHOLDS BELOW POVERTY'])

# Add labels and title
plt.xlabel('Percent of Aged 16+ Unemployed')
plt.ylabel('Percent of Households Below Poverty')
plt.title('Unemployment vs Poverty Level')

# Show the plot
plt.show()

# %%
# Create a scatter plot
plt.scatter(df['PERCENT OF HOUSING CROWDED'], df['PERCENT HOUSEHOLDS BELOW POVERTY'])

# Add labels and title
plt.xlabel('Percent of Crowded Housing')
plt.ylabel('Percent of Households Below Poverty')
plt.title('Crowded Housing vs Poverty Level')

# Show the plot
plt.show()

# %%
#Consider removing or not including all columns

#Calcuate coefficient
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                                               Community Area Number  \
# Community Area Number                                      1.000000
# PERCENT OF HOUSING CROWDED                                 0.002316
# PERCENT HOUSEHOLDS BELOW POVERTY                           0.147414
# PERCENT AGED 16+ UNEMPLOYED                                0.376196
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA               0.175969
# PERCENT AGED UNDER 18 OR OVER 64                           0.428011
# PER CAPITA INCOME                                         -0.398344
# HARDSHIP INDEX                                             0.314853
#
#                                               PERCENT OF HOUSING CROWDED  \
# Community Area Number                                           0.002316
# PERCENT OF HOUSING CROWDED                                      1.000000
# PERCENT HOUSEHOLDS BELOW POVERTY                                0.319403
# ...

# %%
#Consider removing or not including all columns

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='flare', fmt=".2f", square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
#Consider removing or not including all columns
sns.pairplot(df)
plt.show()

# %%
#Create scatter plot 
scatter_plot = df.plot(kind="scatter", x="PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "High School Diploma vs Poverty Level", color='#33AFFF')

# Create x and y values 
x_values=df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regress 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'#3633FF')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 0.41x + 13.33

# %%
#Create scatter plot 
scatter_plot = df.plot(kind="scatter", x="PERCENT AGED 16+ UNEMPLOYED", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Unemployment vs Poverty Level", color='#33AFFF')

# Create x and y values 
x_values=df['PERCENT AGED 16+ UNEMPLOYED']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regress 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'#3633FF')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 1.22x + 2.99

# %%
#Create scatter plot 
scatter_plot = df.plot(kind="scatter", x="PERCENT OF HOUSING CROWDED", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Crowded Housing vs Poverty Level", color='#33AFFF')

# Create x and y values 
x_values=df['PERCENT OF HOUSING CROWDED']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regress 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'#3633FF')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 1.0x + 16.82
