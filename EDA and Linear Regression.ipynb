# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st

# %%
# Read CSV in as a dataframe
df = pd.read_csv('Data/census_data.csv')

# Print df
df
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# ...

# %%
# First five rows of the dataframe
df.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# ...

# %%
# Drop commmunity area number and hardship index
df.drop(['Community Area Number', 'HARDSHIP INDEX'], axis = 1, inplace = True) 
df
# Out:
#    COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0          Rogers Park                         7.7
# 1           West Ridge                         7.8
# 2               Uptown                         3.8
# 3       Lincoln Square                         3.4
# 4         North Center                         0.3
# ..                 ...                         ...
# 73     Mount Greenwood                         1.0
# 74         Morgan Park                         0.8
# 75              O'Hare                         3.6
# 76           Edgewater                         4.1
# 77             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                               23.6                          8.7
# 1                               17.2                          8.8
# 2                               24.0                          8.9
# 3                               10.9                          8.2
# ...

# %%
# See statistical summary 
df.describe()
# Out:
#        PERCENT OF HOUSING CROWDED  PERCENT HOUSEHOLDS BELOW POVERTY  \
# count                   78.000000                         78.000000
# mean                     4.920513                         21.739744
# std                      3.658981                         11.457231
# min                      0.300000                          3.300000
# 25%                      2.325000                         13.350000
# 50%                      3.850000                         19.050000
# 75%                      6.800000                         29.150000
# max                     15.800000                         56.500000
#
#        PERCENT AGED 16+ UNEMPLOYED  \
# count                    78.000000
# mean                     15.341026
# std                       7.499497
# min                       4.700000
# 25%                       9.200000
# 50%                      13.850000
# 75%                      20.000000
# max                      35.900000
#
# ...

# %%
# Data types
df.dtypes
# Out:
# COMMUNITY AREA NAME                              object
# PERCENT OF HOUSING CROWDED                      float64
# PERCENT HOUSEHOLDS BELOW POVERTY                float64
# PERCENT AGED 16+ UNEMPLOYED                     float64
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA    float64
# PERCENT AGED UNDER 18 OR OVER 64                float64
# PER CAPITA INCOME                                 int64
# dtype: object

# %%
#Check for missing values
df.isna()
# Out:
#     COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                 False                       False
# 1                 False                       False
# 2                 False                       False
# 3                 False                       False
# 4                 False                       False
# ..                  ...                         ...
# 73                False                       False
# 74                False                       False
# 75                False                       False
# 76                False                       False
# 77                False                       False
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# ...

# %%
# Check for duplicates 
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Length: 78, dtype: bool

# %%
# Create histogram for Percent Households below Poverty field 
plt.hist(df['PERCENT HOUSEHOLDS BELOW POVERTY'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percentage Households Below Poverty')
plt.ylabel('Frequency')
plt.title('Distribution of Percent Households Below Poverty')

# Show the plot
plt.show()

# %%
# Create histogram for Percent Aged 16+ Unemployed field
plt.hist(df['PERCENT AGED 16+ UNEMPLOYED'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percentage Aged 16+ Unemployed')
plt.ylabel('Frequency')
plt.title('Distribution of Unemployement Percentage')

# Show the plot
plt.show()

# %%
# Create a histogram for Percent of Housing Crowded field
plt.hist(df['PERCENT OF HOUSING CROWDED'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percentage of Housing Crowded')
plt.ylabel('Frequency')
plt.title('Distribution of Housing Crowded Percentage')

# Show the plot
plt.show()

# %%
# Create histogram for Percent Aged 25+ Without High School Diploma field
plt.hist(df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA'], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Percentage aged 25+ without High School Diploma')
plt.ylabel('Frequency')
plt.title('Distribution of Percentage without High School Diploma')

# Show the plot
plt.show()

# %%
# Create histogram for Per Capita Income field
plt.hist(df["PER CAPITA INCOME"], bins=5, color='#33AFFF', edgecolor='black')

# Add labels and title
plt.xlabel('Per Capita Income')
plt.ylabel('Frequency')
plt.title('Distribution of Per Capita Income')

# Show the plot
plt.show()

# %%
# Create Pairplot
sns.pairplot(df)
plt.show()

# %%
# Create Correlation Coefficient Matrix
correlation_matrix = df[["PERCENT HOUSEHOLDS BELOW POVERTY", "PERCENT OF HOUSING CROWDED", "PERCENT AGED 16+ UNEMPLOYED", "PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA", "PERCENT AGED UNDER 18 OR OVER 64", "PER CAPITA INCOME"]].corr()
correlation_matrix
# Out:
#                                               PERCENT HOUSEHOLDS BELOW POVERTY  \
# PERCENT HOUSEHOLDS BELOW POVERTY                                      1.000000
# PERCENT OF HOUSING CROWDED                                            0.319403
# PERCENT AGED 16+ UNEMPLOYED                                           0.800084
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                          0.424294
# PERCENT AGED UNDER 18 OR OVER 64                                      0.435894
# PER CAPITA INCOME                                                    -0.567025
#
#                                               PERCENT OF HOUSING CROWDED  \
# PERCENT HOUSEHOLDS BELOW POVERTY                                0.319403
# PERCENT OF HOUSING CROWDED                                      1.000000
# PERCENT AGED 16+ UNEMPLOYED                                     0.165299
# PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA                    0.875959
# ...

# %%
# Create Heatmap 
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt=".2f", square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
#Create scatter plot for Percent Aged 15+ Without High School Diploma and Percent Households Below Povery
scatter_plot = df.plot(kind="scatter", x="PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Relationship between High School Diploma and Poverty Level", color='#33AFFF')

# Create x and y values 
x_values=df['PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regression 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'#3633FF')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 0.41x + 13.33

# %%
#Create scatter plot for Percent Aged 16+ Unemployed and Percent Households Below Povery
scatter_plot = df.plot(kind="scatter", x="PERCENT AGED 16+ UNEMPLOYED", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Relationship between Unemployment and Poverty Level", color='#33AFFF')

# Create x and y values 
x_values=df['PERCENT AGED 16+ UNEMPLOYED']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regression
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'#3633FF')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 1.22x + 2.99

# %%
#Create scatter plot for Percent of Housing Crowded and Percent Households Below Povery
scatter_plot = df.plot(kind="scatter", x="PERCENT OF HOUSING CROWDED", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Relationship between Crowded Housing and Poverty Level", color='#33AFFF')

# Create x and y values 
x_values=df['PERCENT OF HOUSING CROWDED']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regression 
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'#3633FF')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = 1.0x + 16.82

# %%
#Create scatter plot for Per Capita Income and Percent Households Below Povery
scatter_plot = df.plot(kind="scatter", x="PER CAPITA INCOME", y="PERCENT HOUSEHOLDS BELOW POVERTY", grid=True, figsize=(10,8), title= "Relationship between Per Capita Income and Poverty Level", color='#33AFFF')

# Create x and y values 
x_values=df['PER CAPITA INCOME']
y_values=df['PERCENT HOUSEHOLDS BELOW POVERTY']

# Calculate linear regression
(slope, intercept,  rvalue, pvalue, stderr)= st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,'#3633FF')
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f'Linear regression equation: {line_eq}')

# Show plot 
plt.show()
# Out:
# Linear regression equation: y = -0.0x + 32.68
